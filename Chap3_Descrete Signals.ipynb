# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import scienceplots
import math

# %%
plt.style.use(['science', 'notebook', 'grid'])

# %%
def impD(n):
    y = signal.unit_impulse(n)
    return y

# %%
n = np.arange(-10, 10, 1)
x = impD(n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7656\3086569780.py in <module>
#       1 n = np.arange(-10, 10, 1)
# ----> 2 x = impD(n)
#
# ~\AppData\Local\Temp\ipykernel_7656\467523878.py in impD(n)
#       1 def impD(n):
# ----> 2     y = signal.unit_impulse(n)
#       3     return y
#
# ~\anaconda3\lib\site-packages\scipy\signal\_waveforms.py in unit_impulse(shape, idx, dtype)
#     650
#     651     """
# --> 652     out = zeros(shape, dtype)
#     653
#     654     shape = np.atleast_1d(shape)
#
# ValueError: negative dimensions are not allowed

# %%
plt.figure(figsize=(8,3))
plt.stem(n, x)
plt.xlabel('$t$', fontsize=12)
plt.ylabel('$u(t)$', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7656\480087682.py in <module>
#       1 plt.figure(figsize=(8,3))
# ----> 2 plt.stem(n, x)
#       3 plt.xlabel('$t$', fontsize=12)
#       4 plt.ylabel('$u(t)$', fontsize=12)
#       5 plt.tick_params(axis='both', which='major', labelsize=12)
#
# NameError: name 'x' is not defined

# %%
def usD(n):
    y = np.heaviside(n, 1)
    return y

# %%
n = np.arange(-10, 10, 1)
x = usD(n)

# %%
plt.figure(figsize=(8,3))
plt.stem(n, x)
plt.xlabel('$t$', fontsize=12)
plt.ylabel('$u(t)$', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %%
def signD(n):
    y = np.sign(n)
    return y

# %%
n = np.arange(-10, 10, 1)
x = signD(n)

# %%
plt.figure(figsize=(8,3))
plt.stem(n, x)
plt.xlabel('$t$', fontsize=12)
plt.ylabel('$u(t)$', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %%
def rampD(n):
    y = n * usD(n)
    return y

# %%
n = np.arange(-10, 10, 1)
x = rampD(n)

# %%
plt.figure(figsize=(8,3))
plt.stem(n, x)
plt.xlabel('$t$', fontsize=12)
plt.ylabel('$u(t)$', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()
